# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('OncologyScreenLINCS_PRISM.csv')
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# drugname1    0
# drugname2    0
# cellline     0
# score        0
# dtype: int64
# 0

# %%
x_test = df.drop(['score'], axis=1)
y_test = df['score']

4
